# %%
import pandas as pd
data_frame = pd.read_csv('data.csv', encoding= 'ISO-8859-1')
data_frame
# Out:
#        Unnamed: 0      ID                Name   Age  \
# 0               0  158023            L. Messi  31.0
# 1               1   20801   Cristiano Ronaldo  33.0
# 2               2  190871           Neymar Jr  26.0
# 3               3  193080              De Gea  27.0
# 4               4  192985        K. De Bruyne  27.0
# ...           ...     ...                 ...   ...
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
#describe features
data_frame.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18206.000000  18206.000000  18207.000000
# mean    9103.000000  214298.338606     25.122048     66.237449     71.307299
# std     5256.052511   29965.244204      4.670022      6.907059      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
#first 5 row
data_frame.head()
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 2           2  190871          Neymar Jr  26.0
# 3           3  193080             De Gea  27.0
# 4           4  192985       K. De Bruyne  27.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94
# 1  https://cdn.sofifa.org/flags/38.png     94.0         94
# 2  https://cdn.sofifa.org/flags/54.png     92.0         93
# 3  https://cdn.sofifa.org/flags/45.png     91.0         93
# ...

# %%
#last 5 rows
data_frame.tail()
# Out:
#        Unnamed: 0      ID                Name   Age  \
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png     47.0         65
# 18203  https://cdn.sofifa.org/flags/46.png     47.0         63
# ...

# %%
#Histogram
data_frame["Age"].hist()
# Out:
# <Axes: >

# %%
data_frame["Nationality"].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
#Selecting by feature
data_frame['Name'].head()
# Out:
# 0             L. Messi
# 1    Cristiano Ronaldo
# 2            Neymar Jr
# 3               De Gea
# 4         K. De Bruyne
# Name: Name, dtype: object

# %%
data_frame[data_frame['Age'] > 30].head()
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 6           6  177003          L. Modri?  32.0
# 7           7  176580          L. Suárez  31.0
# 8           8  155862       Sergio Ramos  32.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8  https://cdn.sofifa.org/players/4/19/155862.png       Spain
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png     94.0         94      Juventus  ...
# ...

# %%
#Sorting!
data_frame.sort_values("Age", ascending=True).head()
# Out:
#        Unnamed: 0      ID         Name   Age  \
# 18206       18206  246269    G. Nugent  16.0
# 17743       17743  244752    J. Olstad  16.0
# 13293       13293  246594  H. Massengo  16.0
# 16081       16081  241552  J. Italiano  16.0
# 18166       18166  243621     N. Ayéva  16.0
#
#                                                 Photo Nationality  \
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
# 17743  https://cdn.sofifa.org/players/4/19/244752.png      Norway
# 13293  https://cdn.sofifa.org/players/4/19/246594.png      France
# 16081  https://cdn.sofifa.org/players/4/19/241552.png   Australia
# 18166  https://cdn.sofifa.org/players/4/19/243621.png      Sweden
#
#                                        Flag  Overall  Potential  \
# 18206   https://cdn.sofifa.org/flags/14.png     46.0         66
# 17743   https://cdn.sofifa.org/flags/36.png     52.0         69
# 13293   https://cdn.sofifa.org/flags/18.png     62.0         75
# ...

# %%
#Grouping
overall_group = data_frame.groupby('Overall')
overall_group

# %%
#Selecting row
data_frame.iloc[0,:]
# Out:
# Unnamed: 0                                                     0
# ID                                                        158023
# Name                                                    L. Messi
# Age                                                         31.0
# Photo             https://cdn.sofifa.org/players/4/19/158023.png
#                                        ...
# GKHandling                                                  11.0
# GKKicking                                                   15.0
# GKPositioning                                               14.0
# GKReflexes                                                   8.0
# Release Clause                                           226.5M
# Name: 0, Length: 89, dtype: object

# %%
data_frame.iloc[0,2]
# Out:
# 'L. Messi'

# %%
data_frame.loc[1]
# Out:
# Unnamed: 0                                                    1
# ID                                                        20801
# Name                                          Cristiano Ronaldo
# Age                                                        33.0
# Photo             https://cdn.sofifa.org/players/4/19/20801.png
#                                       ...
# GKHandling                                                 11.0
# GKKicking                                                  15.0
# GKPositioning                                              14.0
# GKReflexes                                                 11.0
# Release Clause                                          127.1M
# Name: 1, Length: 89, dtype: object

# %%
# Rows with at least one NaN value
data_frame[pd.isnull(data_frame).any(axis=1)]
# Out:
#        Unnamed: 0      ID                Name   Age  \
# 0               0  158023            L. Messi  31.0
# 1               1   20801   Cristiano Ronaldo  33.0
# 2               2  190871           Neymar Jr  26.0
# 3               3  193080              De Gea  27.0
# 4               4  192985        K. De Bruyne  27.0
# ...           ...     ...                 ...   ...
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# Drop rows with Nan values
# data_frame = data_frame.dropna() # removes rows with any NaN values
# data_frame = data_frame.reset_index() # reset's row indexes in case any rows were dropped
# data_frame.head()
# Out:
# Empty DataFrame
# Columns: [level_0, index, Unnamed: 0, ID, Name, Age, Photo, Nationality, Flag, Overall, Potential, Club, Club Logo, Value, Wage, Special, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Real Face, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, LS, ST, RS, LW, LF, CF, RF, RW, LAM, CAM, RAM, LM, LCM, CM, RCM, RM, LWB, LDM, CDM, RDM, RWB, LB, LCB, CB, RCB, RB, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause]
# Index: []
#
# [0 rows x 91 columns]

# %%
# Dropping multiple columns, axis = 1 , is column. axis = 0 is rows
#data_frame = data_frame.drop(["Name", "Photo", "Age"], axis=1) # we won't use text features for our initial basic models
#data_frame.head()
# Out:
#    Unnamed: 0      ID Nationality                                 Flag  \
# 0           0  158023   Argentina  https://cdn.sofifa.org/flags/52.png
# 1           1   20801    Portugal  https://cdn.sofifa.org/flags/38.png
# 2           2  190871      Brazil  https://cdn.sofifa.org/flags/54.png
# 3           3  193080       Spain  https://cdn.sofifa.org/flags/45.png
# 4           4  192985     Belgium   https://cdn.sofifa.org/flags/7.png
#
#    Overall  Potential                 Club  \
# 0     94.0         94         FC Barcelona
# 1     94.0         94             Juventus
# 2     92.0         93  Paris Saint-Germain
# 3     91.0         93    Manchester United
# 4     91.0         92      Manchester City
#
#                                       Club Logo    Value   Wage  ...  \
# 0  https://cdn.sofifa.org/teams/2/light/241.png  110.5M  565K  ...
# 1   https://cdn.sofifa.org/teams/2/light/45.png     77M  405K  ...
# ...

# %%
# Out:
#        Unnamed: 0      ID                Name   Age  \
# 0               0  158023            L. Messi  31.0
# 1               1   20801   Cristiano Ronaldo  33.0
# 2               2  190871           Neymar Jr  26.0
# 3               3  193080              De Gea  27.0
# 4               4  192985        K. De Bruyne  27.0
# ...           ...     ...                 ...   ...
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# Out:
#        Unnamed: 0      ID                Name   Age  \
# 0               0  158023            L. Messi  31.0
# 1               1   20801   Cristiano Ronaldo  33.0
# 2               2  190871           Neymar Jr  26.0
# 3               3  193080              De Gea  27.0
# 4               4  192985        K. De Bruyne  27.0
# ...           ...     ...                 ...   ...
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
#Save
data_frame.to_csv("processed_soccer.csv", index=False)

# %%
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
